# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajyalaxmi29/Rajyalaxmi29/blob/main/pandasday2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/zynicide/wine-reviews?select=winemag-data-130k-v2.csv")
# Out:
# Skipping, found downloaded files in "./wine-reviews" (use force=True to force download)

# %%
import pandas as pd
df=pd.read_csv("/content/wine-reviews/winemag-data-130k-v2.csv")
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %% [markdown]
# ❓ Question 1
#
# What is the average (mean) value of the points column in the reviews DataFrame?
#
# 📌 Instructions:
#
# Use one pandas function
#
# Store the result in a variable called avg_points

# %%
df.points.mean()
# Out:
# np.float64(88.44713820775404)

# %% [markdown]
# ❓ Question 2
#
# Which different countries are present in the dataset?
# (Remove duplicates.)
#
# 📌 Instructions:
#
# Use one pandas function
#
# Store the result in a variable called countries

# %%
countries=df.country.unique()
countries
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %% [markdown]
# How many wine reviews are there for each country?
#
# 📌 Instructions:
#
# Use one pandas function
#
# Store the result in a variable called reviews_per_country

# %%
reviews_per_country=df.country.value_counts()
reviews_per_country
# Out:
# country
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %% [markdown]
# ❓ Question 4
#
# Create a new Series called centered_points where the mean of the points column is subtracted from each value.
#
# 📌 Instructions:
#
# Do not use map() or apply()
#
# Use vectorized pandas operation
#
# Store result in centered_points

# %%
centered_points=df.points - df.points.mean()
centered_points
# Out:
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
#             ...
# 129966    1.552862
# 129967    1.552862
# 129968    1.552862
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %% [markdown]
# ❓ Question 5
#
# Which wine is the best bargain?
#
# 👉 Best bargain means:
#
# the wine with the highest points-to-price ratio
#
# 📌 What you need to do (thinking steps, not code):
#
# Divide points by price
#
# Find the index of the maximum value
#
# Use that index to get the wine title
#
# 📌 Instruction:
#
# Store the final answer in a variable named best_bargain

# %%
d=(df.points/df.price).idxmax()
a=df.loc[d,'title']
a
# Out:
# 'Bandit NV Merlot (California)'

# %% [markdown]
# ❓ Question 6
#
# Which word appears more often in wine descriptions: "tropical" or "fruity"?
#
# 📌 Instructions:
#
# Look only at the description column
#
# Ignore capitalization
#
# Count how many times each word appears
#
# Store the result in a Series called word_counts
#
# Index: ['tropical', 'fruity']
#
# Values: their counts

# %%
tropical=df.description.map(lambda x:"tropical" in x).sum()
fruit=df.description.map(lambda x:"fruity" in x).sum()
w_c=pd.Series([tropical,fruit],index=['tropical','fruity'])
w_c
# Out:
# tropical    3607
# fruity      9090
# dtype: int64

# %% [markdown]
# ❓ Question
#
# Create a new Series called quality_label such that:
#
# "Good" → if points ≥ 90
#
# "Average" → if points < 90
#
# 📌 Instructions:
#
# Use apply()
#
# Use one simple if / else
#
# Work only with the points column
# Hint (thinking, not code)
#
# Take one row
#
# Look at row.points
#
# Decide "Good" or "Average"
#
# Return the label
#
# Use apply(axis='columns')

# %%
def q(r):
  if r.points>=90:
    return "good"
  else:
    return "average"
q_l=df.apply(q,axis='columns')
q_l
# Out:
# 0         average
# 1         average
# 2         average
# 3         average
# 4         average
#            ...
# 129966       good
# 129967       good
# 129968       good
# 129969       good
# 129970       good
# Length: 129971, dtype: object

# %% [markdown]
# ❓ Question
#
# Using axis='index', calculate the range (max − min) for each numeric column in the dataset.
#
# 📌 Instructions:
#
# Use apply()
#
# Use axis='index'
#
# Use max() and min()

# %%
ndf=df.select_dtypes(include='number')
f=ndf.apply(lambda x:x.max()-x.min(),axis='index')
f
# Out:
# Unnamed: 0    129970.0
# points            20.0
# price           3296.0
# dtype: float64

# %% [markdown]
# ❓ Question
#
# Using axis='index', count the number of non-null values in each numeric column.

# %%
ndf=df.select_dtypes(include="number")
# a=ndf.apply(lambda x:x.notnull().value_counts(),axis='index')
# a
s=ndf.apply(lambda x:x.notnull().sum(),axis='index')
s
# Out:
# Unnamed: 0    129971
# points        129971
# price         120975
# dtype: int64

# %% [markdown]
# ❓ Your Task
#
# Using the Wine Reviews dataset, do the following:
#
# Consider only wines where price is available (price is NOT null).
#
# From those wines, select wines that have points ≥ 90.
#
# For the filtered wines:
#
# Create a new column called Value_Score defined as
#
# Value_Score = points / price
#
#
# Identify the top 5 wines with the highest Value_Score.
#
# From the final result, display only these columns:
#
# title
#
# country
#
# points
#
# price
#
# **Value_Score**

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
ndf=df.loc[df.price.notnull()]
ndf
# Out:
#         Unnamed: 0   country  \
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# 5                5     Spain
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 5       Blackberry and raspberry aromas show a typical...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
ndf.loc[(ndf.points>=90)]
# Out:
#         Unnamed: 0    country  \
# 119            119     France
# 120            120      Italy
# 121            121         US
# 122            122         US
# 123            123  Australia
# ...            ...        ...
# 129966      129966    Germany
# 129967      129967         US
# 129968      129968     France
# 129969      129969     France
# 129970      129970     France
#
#                                               description  \
# 119     Medium-gold in color. Complex and inviting nos...
# 120     Slightly backward, particularly given the vint...
# 121     The vineyard is one of the better Chardonnay s...
# 122     Defines Rockpile Zinfandel in intensity of fru...
# 123     The blend is roughly two-thirds Shiraz and one...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
v_s=(ndf.points/ndf.price)
ndf['v_s']=v_s
ndf=ndf.sort_values('v_s',ascending=False)
ndf.head()
# Out:
# /tmp/ipython-input-3744126940.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf['v_s']=v_s
#         Unnamed: 0  country  \
# 126096      126096  Romania
# 64590        64590       US
# 1987          1987    Spain
# 20484        20484       US
# 110255      110255       US
#
#                                               description  designation  \
# 126096  Notes of sun-dried hay and green flower highli...      UnWineD
# 64590   There's a lot going on in this Merlot, which i...          NaN
# 1987    Berry and cherry aromas are surprisingly sturd...  Flirty Bird
# 20484   Fruity, soft and rather sweet, this wine smell...          NaN
# 110255  A good everyday Merlot, dry and rich in tannin...          NaN
#
# ...

# %%
ndf.loc[:,['title','country','points','price','v_s']].head(5)
# Out:
#                                                     title  country  points  \
# 126096  Cramele Recas 2011 UnWineD Pinot Grigio (Viile...  Romania      86
# 64590                       Bandit NV Merlot (California)       US      86
# 1987    Felix Solis 2013 Flirty Bird Syrah (Vino de la...    Spain      85
# 20484              Dancing Coyote 2015 White (Clarksburg)       US      85
# 110255                      Bandit NV Merlot (California)       US      84
#
#         price    v_s
# 126096    4.0  21.50
# 64590     4.0  21.50
# 1987      4.0  21.25
# 20484     4.0  21.25
# 110255    4.0  21.00

# %% [markdown]
# 🧩 QUESTION 1: Reviewer Consistency Check (Different Thinking)
# Scenario
#
# The quality team wants to know if reviewers are consistent or biased.
#
# Task
#
# Calculate the average points across all wines.
#
# Create a new column Above_Average:
#
# True if a wine’s points are greater than the overall average
#
# False otherwise
#
# Display only:
#
# title
#
# taster_name
#
# points
#
# Above_Average
#
# Show only the first 10 rows.

# %%
n1df=df.points.mean()
n1df
# Out:
# np.float64(88.44713820775404)

# %%
n1df=df.points.mean()
# def q(r):
#   if r.points>n1df:
#     return True
#   else:
#     return False
df['above_avg']=df.points>n1df
df.head(10)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
# 6           6     Italy  Here's a bright, informal red that opens with ...
# 7           7    France  This dry and restrained wine offers spice in p...
# 8           8   Germany  Savory dried thyme notes accent sunnier flavor...
# 9           9    France  This has great depth of flavor with its fresh ...
#
#                           designation  points  price           province  \
# ...

# %%
# ❓ Question

# Create a new column Title_Length that contains the number of characters in each wine’s title,
# and then display the top 5 wines with the longest titles.
df['title_len']=df.title.str.len()
df=df.sort_values('title_len',ascending=False)
# df.head(5)
ndf=df.loc[:,['title']].head(5)
ndf
# Out:
#                                                     title
# 120012  Pascual Toso 2012 Magdalena Toso Limited 32 Ba...
# 15000   Véronique Günther-Chereau 2014 Château du Coin...
# 15486   Reynvaan Family Vineyards 2013 The Classic Est...
# 25995   Tablas Creek 2015 Côtes de Tablas Blanc Estate...
# 14683   Tablas Creek 2010 Esprit de Beaucastel Blanc G...
